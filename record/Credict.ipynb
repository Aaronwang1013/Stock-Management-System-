# %%
import pandas as pd

# %%
df = pd.read_csv('/home/aaron/Downloads/Download(2).csv' , encoding = 'big5' , header = 1 , on_bad_lines='skip')

# %%
df
# Out:
#   帳單結帳日：110/09/15 繳款截止日（遇假日順延）：110/10/05/請儘速繳款
# 0                                        帳務資訊：
# 1                                        帳單資訊：
# 2                                        紅利點數：
# 3                                您本月各幣別消費明細如下：
# 4                                         新臺幣：
# 5                                          美元：

# %%
import requests
from io import StringIO
import pandas as pd

# %%
import os
os.path.join('./' , 'templates')
# Out:
# './templates'

# %%
from datetime import date
today = date.today()
d1 = today.strftime("%Y%m%d")
d1
# Out:
# '20220825'

# %%
date = '20220824'
r = requests.get('http://www.tse.com.tw/fund/T86?response=csv&date='+date+'&selectType=ALLBUT0999')

df = pd.read_csv(StringIO(r.text) , header = 1).dropna(how='all' ,axis =1 ).dropna(how='any')

# %%
r
# Out:
# <Response [200]>

# %%
pd.read_csv(StringIO(r.text) , header = 1).dropna(how='all' , axis =1 ).dropna(how='any')
# Out:
#            證券代號            證券名稱 外陸資買進股數(不含外資自營商) 外陸資賣出股數(不含外資自營商)  \
# 0     ="00715L"       期街口布蘭特正2         1,075,000          920,000
# 1          5258  虹堡                   12,927,000        4,777,370
# 2     ="00642U"     期元大S&P石油              37,000           37,000
# 3          2867   三商壽                  5,220,000          360,000
# 4          2838   聯邦銀                  5,757,000        1,374,000
# ...         ...             ...              ...              ...
# 1101   ="00882"       中信中國高股息            520,000          665,000
# 1102    ="0056"     元大高股息                916,102          896,000
# 1103       2887   台新金                 23,843,501       46,082,037
# 1104  ="00673R"      期元大S&P原油反1          433,000          254,000
# 1105   ="00878"       國泰永續高股息          1,302,328       10,715,000
#
#      外陸資買賣超股數(不含外資自營商)  外資自營商買進股數  外資自營商賣出股數  外資自營商買賣超股數     投信買進股數 投信賣出股數  \
# 0              155,000        0.0        0.0         0.0          0      0
# 1            8,149,630        0.0        0.0         0.0          0      0
# 2                    0        0.0        0.0         0.0          0      0
# 3            4,860,000        0.0        0.0         0.0          0      0
# 4            4,383,000        0.0        0.0         0.0          0      0
# ...                ...        ...        ...         ...        ...    ...
# 1101          -145,000        0.0        0.0         0.0          0      0
# 1102            20,102        0.0        0.0         0.0          0      0
# 1103       -22,238,536        0.0        0.0         0.0     18,000      0
# 1104           179,000        0.0        0.0         0.0          0      0
# 1105        -9,412,672        0.0        0.0         0.0  1,924,000      0
#
#         投信買賣超股數     自營商買賣超股數 自營商買進股數(自行買賣) 自營商賣出股數(自行買賣) 自營商買賣超股數(自行買賣)  \
# 0             0   23,974,000             0             0              0
# 1             0       -8,000             0         8,000         -8,000
# 2             0    5,417,099             0             0              0
# 3             0       14,000         1,000             0          1,000
# 4             0            0             0             0              0
# ...         ...          ...           ...           ...            ...
# 1101          0  -17,764,362             0             0              0
# 1102          0  -19,900,704        50,000             0         50,000
# 1103     18,000   -1,351,827       281,000       189,586         91,414
# 1104          0  -28,567,771             0             0              0
# 1105  1,924,000  -26,082,276             0             0              0
#
#      自營商買進股數(避險) 自營商賣出股數(避險) 自營商買賣超股數(避險)    三大法人買賣超股數
# 0     24,872,000     898,000   23,974,000   24,129,000
# 1              0           0            0    8,141,630
# 2      5,753,099     336,000    5,417,099    5,417,099
# 3         13,000           0       13,000    4,874,000
# 4              0           0            0    4,383,000
# ...          ...         ...          ...          ...
# 1101     561,000  18,325,362  -17,764,362  -17,909,362
# 1102     733,999  20,684,703  -19,950,704  -19,880,602
# 1103     676,000   2,119,241   -1,443,241  -23,572,363
# 1104   2,087,000  30,654,771  -28,567,771  -28,388,771
# 1105   6,008,000  32,090,276  -26,082,276  -33,570,948
#
# [1106 rows x 19 columns]

# %%
df = df.astype(str).apply(lambda s: s.str.replace('"' , ''))

# %%
df['stock_id'] = df['證券代號'].str.replace('=' , '').str.replace('"' , '')

# %%
df
# Out:
#          證券代號            證券名稱 外陸資買進股數(不含外資自營商) 外陸資賣出股數(不含外資自營商)  \
# 0     =00715L       期街口布蘭特正2         1,075,000          920,000
# 1        5258  虹堡                   12,927,000        4,777,370
# 2     =00642U     期元大S&P石油              37,000           37,000
# 3        2867   三商壽                  5,220,000          360,000
# 4        2838   聯邦銀                  5,757,000        1,374,000
# ...       ...             ...              ...              ...
# 1101   =00882       中信中國高股息            520,000          665,000
# 1102    =0056     元大高股息                916,102          896,000
# 1103     2887   台新金                 23,843,501       46,082,037
# 1104  =00673R      期元大S&P原油反1          433,000          254,000
# 1105   =00878       國泰永續高股息          1,302,328       10,715,000
#
#      外陸資買賣超股數(不含外資自營商) 外資自營商買進股數 外資自營商賣出股數 外資自營商買賣超股數     投信買進股數 投信賣出股數  \
# 0              155,000       0.0       0.0        0.0          0      0
# 1            8,149,630       0.0       0.0        0.0          0      0
# 2                    0       0.0       0.0        0.0          0      0
# 3            4,860,000       0.0       0.0        0.0          0      0
# 4            4,383,000       0.0       0.0        0.0          0      0
# ...                ...       ...       ...        ...        ...    ...
# 1101          -145,000       0.0       0.0        0.0          0      0
# 1102            20,102       0.0       0.0        0.0          0      0
# 1103       -22,238,536       0.0       0.0        0.0     18,000      0
# 1104           179,000       0.0       0.0        0.0          0      0
# 1105        -9,412,672       0.0       0.0        0.0  1,924,000      0
#
#         投信買賣超股數     自營商買賣超股數 自營商買進股數(自行買賣) 自營商賣出股數(自行買賣) 自營商買賣超股數(自行買賣)  \
# 0             0   23,974,000             0             0              0
# 1             0       -8,000             0         8,000         -8,000
# 2             0    5,417,099             0             0              0
# 3             0       14,000         1,000             0          1,000
# 4             0            0             0             0              0
# ...         ...          ...           ...           ...            ...
# 1101          0  -17,764,362             0             0              0
# 1102          0  -19,900,704        50,000             0         50,000
# 1103     18,000   -1,351,827       281,000       189,586         91,414
# 1104          0  -28,567,771             0             0              0
# 1105  1,924,000  -26,082,276             0             0              0
#
#      自營商買進股數(避險) 自營商賣出股數(避險) 自營商買賣超股數(避險)    三大法人買賣超股數 stock_id
# 0     24,872,000     898,000   23,974,000   24,129,000   00715L
# 1              0           0            0    8,141,630     5258
# 2      5,753,099     336,000    5,417,099    5,417,099   00642U
# 3         13,000           0       13,000    4,874,000     2867
# 4              0           0            0    4,383,000     2838
# ...          ...         ...          ...          ...      ...
# 1101     561,000  18,325,362  -17,764,362  -17,909,362    00882
# 1102     733,999  20,684,703  -19,950,704  -19,880,602     0056
# 1103     676,000   2,119,241   -1,443,241  -23,572,363     2887
# 1104   2,087,000  30,654,771  -28,567,771  -28,388,771   00673R
# 1105   6,008,000  32,090,276  -26,082,276  -33,570,948    00878
#
# [1106 rows x 20 columns]
