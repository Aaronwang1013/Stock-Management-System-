# %%
import pandas as pd
import numpy as np
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash import html
# Out:
# /tmp/ipykernel_7902/484670360.py:7: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# /tmp/ipykernel_7902/484670360.py:8: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
df = pd.read_csv("/home/aaron/Downloads/Download(1).csv",encoding='big5', header = 1)

# %%
##定義需要欄位
# 交易日期

df
# Out:
#         交易日期      時間      提出      存入     餘額     說明  \
# 0   20220129  171936    5000           7699   自行提款
# 1   20220127  140422   45000          12699   網銀轉帳
# 2   20220127  140239           44789  57699   跨行轉入
# 3   20220124  221257   10000          12910   網銀轉帳
# 4   20220124  221221           10000  22910   跨行轉入
# 5   20220124  124657       5          12910   跨行費用
# 6   20220124  124657    2000          12915   跨行提款
# 7   20220122   92304   24397          14915   網銀轉帳
# 8   20220122   92226           24397  39312   跨行轉入
# 9   20220121  191110     130          14915     轉帳
# 10  20220118  131053      10          15045    手續費
# 11  20220118  131053    5155          15055     繳費
# 12  20220115  121408    7206          20210   信用卡款
# 13  20220115  121231    2000          27416   自行提款
# 14  20220109  185650    1500          29416   自行提款
# 15  20220106    1729    3967          30916   網銀轉帳
# 16  20220105  210248           26083  34883   跨行轉入
# 17  20220102  160023    1000           8800   自行提款
#
#                                                  交易資訊  \
# 0
# 1                                0000699508629161 王Ｏ誠
# 2                                    0000720***930751
# 3                                0000699508629161 王Ｏ誠
# 4                                    0000720***930751
# 5
# 6
# 7                                0000699508629161 王Ｏ誠
# 8                                    0000720***930751
# 9               0000030035011133 聯Ｏ商業銀行受託一卡通票證股份有限公司信
# 10
# 11                                   0000000001074790
# 12   02669034193098560 國Ｏ世華商業銀行信用卡作業部 0000007***02...
# 13
# 14
# 15    02806600710800852 裕Ｏ數位資融股份有限公司 0000015***015966
# 16                                   0000720***930751
# 17
#
#                                       備註
# 0                               0130VP1N
# 1
# 2
# 3
# 4
# 5
# 6                     822049500893841999
# 7
# 8
# 9    LINE Pay一卡通儲值  P0012022012100016969
# 10
# 11                              花旗銀行信用卡費
# 12                        國泰世華商業銀行信用卡作業部
# 13                              0130VEE3
# 14                              0130VDBC
# 15                          裕富數位資融股份有限公司
# 16
# 17                              0130VEE3
