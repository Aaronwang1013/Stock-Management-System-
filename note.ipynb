# %%
from webbrowser import get
import numpy as np
import pandas as pd
import requests
import datetime

# %%
url = 'http://fubon-ebrokerdj.fbs.com.tw/z/zg/zgk_d.djhtm' 
r = requests.get(url)
html = r.text

# %%
data = requests.get(url = url).content.decode('big5','replace')

# %%
data
# Out:
# '<!DOCTYPE>\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n<head>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=big5">\r\n<script language="JavaScript"><!--\r\nif (navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1) {\r\n\tif (navigator.userAgent.toLowerCase().match(/msie ([\\d.]+)/)[1] <=10) {\r\n\t\tdocument.writeln(\'<script language="JavaScript" src="/z/js/jquery-latest.djjs"></script>\\n\');\r\n\t} else {\r\n\t\tdocument.writeln(\'<script language="JavaScript" src="/z/js/jquery.djjs"></script>\\n\');\r\n\t}\r\n} else {\r\ndocument.writeln(\'<script language="JavaScript" src="/z/js/jquery.djjs"></script>\\n\');\r\n}\r\n// --></script>\r\n<script language="JavaScript" src="/z/js/jsFunction.djjs"></script>\r\n<script language="JavaScript" src="/z/js/isSpecialKind.djjs"></script>\r\n<script language="JavaScript" src="/z/js/mdj.js"></script>\r\n<script type="text/javascript" src="/z/js/Applet2Canvas.d
# ...

# %%
import re

regex = '<div class="t11">(.*?)</td></tr>'
pattern = re.compile(regex , re.S)
r_list = pattern.findall(data)

# %%
r_list
# Out:
# ['日期：03/30']

# %%
stock = '<td class="t3t1"><a href="javascript:Link2Stk(.*?)">(.*?)</a></TD>'
pattern = re.compile(stock , re.S)
stock_list = pattern.findall(data)

# %%
stock_list
# Out:
# [("('2890')", '2890永豐金'),
#  ("('2834')", '2834臺企銀'),
#  ("('2312')", '2312金寶'),
#  ("('2382')", '2382廣達'),
#  ("('2303')", '2303聯電'),
#  ("('1722')", '1722台肥'),
#  ("('2330')", '2330台積電'),
#  ("('2002')", '2002中鋼'),
#  ("('2891')", '2891中信金'),
#  ("('2313')", '2313華通'),
#  ("('2888')", '2888新光金'),
#  ("('00715L')", '00715L期街口布蘭特正2'),
#  ("('2883')", '2883開發金'),
#  ("('2344')", '2344華邦電'),
#  ("('2887')", '2887台新金'),
#  ("('2356')", '2356英業達'),
#  ("('2881')", '2881富邦金'),
#  ("('3714')", '3714富采'),
#  ("('2886')", '2886兆豐金'),
#  ("('1712')", '1712興農'),
#  ("('2610')", '2610華航'),
#  ("('2454')", '2454聯發科'),
#  ("('2892')", '2892第一金'),
#  ("('2337')", '2337旺宏'),
#  ("('2880')", '2880華南金'),
#  ("('3706')", '3706神達'),
#  ("('3037')", '3037欣興'),
#  ("('00885')", '00885富邦越南'),
#  ("('3189')", '3189景碩'),
#  ("('1709')", '1709和益'),
#  ("('00637L')", '00637L元大滬深300正2'),
#  ("('2603')", '2603長榮'),
#  ("('2884')", '2884玉山金'),
#  ("('1605')", '1605華新'),
#  ("('6282')", '6282康舒'),
# ...

# %%
int(len(stock_list)/2)
# Out:
# 50

# %%
top50_BO = []
for i in range(int(len(stock_list)/2)):
    top50_BO.append(stock_list[i])

# %%
len(top50_BO)
# Out:
# 50

# %%
##讀出來的list是左右各一個排序，一個買超的一個賣超的
#嘗試解決

# %%
len(stock_list)
# Out:
# 100

# %%
from lxml import etree
#rlist = data.xpath('//*[@id="SysJustIFRAMEDIV"]/table/tbody/tr[2]/td[2]/table/tbody/tr/td/form/table/tbody/tr/td/table/tbody/tr[4]/td[2]/a')
parse_html = etree.HTML(url)
r_list = parse_html.xpath('//*[@id="SysJustIFRAMEDIV"]/table/tbody/tr[2]/td[2]/table/tbody/tr/td/form/table/tbody/tr/td/table/tbody/tr[4]/td[2]/a')

# %%
r_list

# %%
r_list
# Out:
# ['',
#  '<',
#  '',
#  '!',
#  '',
#  'D',
#  '',
#  'O',
#  '',
#  'C',
#  '',
#  'T',
#  '',
#  'Y',
#  '',
#  'P',
#  '',
#  'E',
#  '',
#  '>',
#  '',
#  '\r',
#  '',
#  '\n',
#  '',
#  '<',
#  '',
#  'h',
#  '',
#  't',
#  '',
#  'm',
#  '',
#  'l',
#  '',
#  ' ',
#  '',
#  'x',
#  '',
#  'm',
#  '',
#  'l',
#  '',
#  'n',
#  '',
#  's',
#  '',
#  '=',
#  '',
#  '"',
#  '',
#  'h',
#  '',
#  't',
#  '',
#  't',
#  '',
#  'p',
#  '',
#  ':',
#  '',
#  '/',
#  '',
#  '/',
#  '',
#  'w',
#  '',
#  'w',
#  '',
#  'w',
#  '',
#  '.',
#  '',
#  'w',
#  '',
#  '3',
#  '',
#  '.',
#  '',
#  'o',
#  '',
#  'r',
#  '',
#  'g',
#  '',
#  '/',
#  '',
#  '1',
#  '',
#  '9',
#  '',
#  '9',
#  '',
#  '9',
#  '',
#  '/',
#  '',
#  'x',
#  '',
#  'h',
#  '',
#  't',
#  '',
#  'm',
#  '',
#  'l',
#  '',
#  '"',
#  '',
#  '>',
#  '',
#  '\r',
#  '',
#  '\n',
#  '',
#  '<',
#  '',
#  'h',
#  '',
#  'e',
#  '',
#  'a',
#  '',
#  'd',
#  '',
#  '>',
#  '',
#  '\r',
#  '',
#  '\n',
#  '',
#  '<',
# ...

# %%
data
# Out:
# '<!DOCTYPE>\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n<head>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=big5">\r\n<script language="JavaScript"><!--\r\nif (navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1) {\r\n\tif (navigator.userAgent.toLowerCase().match(/msie ([\\d.]+)/)[1] <=10) {\r\n\t\tdocument.writeln(\'<script language="JavaScript" src="/z/js/jquery-latest.djjs"></script>\\n\');\r\n\t} else {\r\n\t\tdocument.writeln(\'<script language="JavaScript" src="/z/js/jquery.djjs"></script>\\n\');\r\n\t}\r\n} else {\r\ndocument.writeln(\'<script language="JavaScript" src="/z/js/jquery.djjs"></script>\\n\');\r\n}\r\n// --></script>\r\n<script language="JavaScript" src="/z/js/jsFunction.djjs"></script>\r\n<script language="JavaScript" src="/z/js/isSpecialKind.djjs"></script>\r\n<script language="JavaScript" src="/z/js/mdj.js"></script>\r\n<script type="text/javascript" src="/z/js/Applet2Canvas.d
# ...

# %%
data
# Out:
# '<!DOCTYPE>\r\n<html xmlns="http://www.w3.org/1999/xhtml">\r\n<head>\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=big5">\r\n<script language="JavaScript"><!--\r\nif (navigator.userAgent.toLowerCase().indexOf(\'msie\') != -1) {\r\n\tif (navigator.userAgent.toLowerCase().match(/msie ([\\d.]+)/)[1] <=10) {\r\n\t\tdocument.writeln(\'<script language="JavaScript" src="/z/js/jquery-latest.djjs"></script>\\n\');\r\n\t} else {\r\n\t\tdocument.writeln(\'<script language="JavaScript" src="/z/js/jquery.djjs"></script>\\n\');\r\n\t}\r\n} else {\r\ndocument.writeln(\'<script language="JavaScript" src="/z/js/jquery.djjs"></script>\\n\');\r\n}\r\n// --></script>\r\n<script language="JavaScript" src="/z/js/jsFunction.djjs"></script>\r\n<script language="JavaScript" src="/z/js/isSpecialKind.djjs"></script>\r\n<script language="JavaScript" src="/z/js/mdj.js"></script>\r\n<script type="text/javascript" src="/z/js/Applet2Canvas.d
# ...

# %%
len(data)
# Out:
# 23284

# %%
http://fubon-ebrokerdj.fbs.com.tw/z/zg/zgk_d.djhtm (外資買賣超一日)
http://fubon-ebrokerdj.fbs.com.tw/z/zg/zgk.djhtm?A=D&B=0&C=5 (外資買賣超五日)
http://fubon-ebrokerdj.fbs.com.tw/z/zg/zgk.djhtm?A=D&B=0&C=10 (外資買賣超十日)

http://fubon-ebrokerdj.fbs.com.tw/Z/ZG/ZGK_DB.djhtm (自營商)


http://fubon-ebrokerdj.fbs.com.tw/Z/ZG/ZGK_DD.djhtm (投信)
http://fubon-ebrokerdj.fbs.com.tw/z/zg/zgk.djhtm?A=DD&B=0&C=5



data
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/tg/whw12mgd5sn034k6d9t1w_7m0000gn/T/ipykernel_71154/1955649738.py in <module>
# ----> 1 data = r.json()
#       2
#       3 data
#
# ~/miniconda3/envs/python/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/miniconda3/envs/python/lib/python3.8/site-packages/simplejson/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     523             parse_constant is None and object_pairs_hook is None
#     524             and not use_decimal and not kw):
# --> 525         return _default_decoder.decode(s)
#     526     if cls is None:
# ...

# %%
data['stat']
# Out:
# 'OK'

# %%
def transform_date(date):
        y, m, d = date.split('/')
        return str(int(y)+1911) + '/' + m  + '/' + d

# %%
transform_date("85/10/13")
# Out:
# '1996/10/13'

# %%
d = [[1,2,3],[4,5,6]]

d[0][0]
# Out:
# 1

# %%
data = data['data']

data
# Out:
# [['111/03/01',
#   '70,303,880',
#   '42,445,208,215',
#   '599.00',
#   '610.00',
#   '599.00',
#   '604.00',
#   ' 0.00',
#   '67,439'],
#  ['111/03/02',
#   '42,428,151',
#   '25,528,700,277',
#   '601.00',
#   '605.00',
#   '600.00',
#   '601.00',
#   '-3.00',
#   '58,916'],
#  ['111/03/03',
#   '37,103,932',
#   '22,373,890,387',
#   '603.00',
#   '607.00',
#   '601.00',
#   '602.00',
#   '+1.00',
#   '65,410'],
#  ['111/03/04',
#   '65,235,167',
#   '38,833,099,256',
#   '595.00',
#   '597.00',
#   '592.00',
#   '595.00',
#   '-7.00',
#   '206,731'],
#  ['111/03/07',
#   '97,167,600',
#   '56,147,025,127',
#   '580.00',
#   '581.00',
#   '575.00',
#   '576.00',
#   '-19.00',
#   '297,917'],
#  ['111/03/08',
#   '88,371,413',
#   '49,908,147,901',
#   '561.00',
#   '570.00',
#   '561.00',
#   '563.00',
#   '-13.00',
#   '269,695'],
#  ['111/03/09',
#   '57,512,412',
#   '32,761,408,119',
#   '567.00',
#   '573.00',
#   '567.00',
#   '568.00',
#   '+5.00',
#   '112,422'],
# ...

# %%
data[0]
# Out:
# ['111/03/01',
#  '70,303,880',
#  '42,445,208,215',
#  '599.00',
#  '610.00',
#  '599.00',
#  '604.00',
#  ' 0.00',
#  '67,439']

# %%
type(data[0])
# Out:
# list

# %%
data[0][0]
# Out:
# '111/03/01'

# %%
datetime.datetime.strptime(transform_date(data[0][0]), '%Y/%m/%d')
# Out:
# datetime.datetime(2022, 3, 1, 0, 0)
